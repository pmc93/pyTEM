# %% [markdown]
# ## Multi-System Inversion Examples
#
# TEM surveys are conducted with a wide range of instrument configurations, from small drone-borne systems to large ground-based loops.  Each system sees a different depth range, has a different noise floor, and applies different instrument corrections (receiver filters and transmitter waveforms).  This notebook compares three representative systems:
#
# | System | Loop | Geometry | Instrument corrections |
# |--------|------|----------|------------------------|
# | Large  | 200 × 200 m | Central square | WalkTEM cascade filter (300 kHz) + 0.4 ms ramp |
# | Medium | 50 × 50 m   | Central square | Butterworth 2nd-order (100 kHz) + 0.2 ms ramp  |
# | Small  | 3 × 3 m     | Offset square  | Butterworth 1st-order (30 kHz) + 0.3 ms ramp   |
#
# For each system the synthetic data are inverted with:
# 1. **Exact square kernel** — slower but exact.
# 2. **Equivalent-area circular kernel** — faster approximation.
# 3. **Circle warm-start** — use the circular inversion result as starting model for the square refinement.
#
# The inversion theory is covered in [Notebook 2](../2.%20pytem_getJ.ipynb); the clean synthetic-example workflow is in [Notebook 3](../3.%20pytem_inv.ipynb).

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

sys.path.insert(0, r'C:\Users\pamcl\OneDrive - Danmarks Tekniske Universitet\Dokumenter\Projects\Python\pyTEM')

from pytem import (
    fwd_circle_central,
    fwd_circle_offset,
    fwd_square_central,
    fwd_square_offset,
    getJ_ana,
    getJ_fd,
    getR,
    getRMS,
    invert,
    butterworth_filter,
    cascade_filter,
    convolve_waveform,
    plot_sounding,
    plot_model,
    plot_inversion,
    MU0,
    HAS_NUMBA,
    HAS_CUDA,
    HANKEL_FILTERS,
    FOURIER_FILTERS,
    EULER_PARAMS,
)

print(f'Numba: {HAS_NUMBA},  CUDA: {HAS_CUDA}')
# Out:
# Numba: True,  CUDA: False

# %% [markdown]
# ## 1. Benchmark Model
#
# A simple 3-layer synthetic model is used throughout all examples:
#
# | Layer | Resistivity | Thickness |
# |-------|------------|-----------|
# | Resistive overburden | 100 Ohm.m | 20 m |
# | Conductive target | 10 Ohm.m | 40 m |
# | Resistive basement | 500 Ohm.m | half-space |
#
# Data are computed over 31 log-spaced time gates from 10 µs to 10 ms.
# Three square-loop configurations are used to span a range of loop sizes and receiver offsets.

# %%
# --- True model ---
rho_true    = np.array([100.0, 10.0, 500.0])   # [Ohm.m]
thick_true  = np.array([20.0, 40.0])           # [m]  (2 layers -> 2 thicknesses)

# --- Survey geometry ---
tx_radius   = np.sqrt(40.**2 / np.pi)           # equivalent circular radius for 40 m loop
tx_side     = 40.0                              # square loop side [m]
rx_offset   = 10.0                              # offset receiver distance [m]

print(f'tx_radius = {tx_radius:.2f} m')
print(f'rho_true  = {rho_true}')
print(f'thick_true = {thick_true}')
# Out:
# tx_radius = 22.57 m
# rho_true  = [100.  10. 500.]
# thick_true = [20. 40.]

# %% [markdown]
# ### 2.1 Build synthetic data
#
# Noise-contaminated synthetic data are generated from the true 3-layer model for each of the three square-loop configurations.
# Gaussian noise is added as a fraction of the signal amplitude, with a noise floor proportional to $t^{-0.5}$.
#
# Each configuration has its own **system filter**, **transmitter waveform**, and **noise level**:
#
# | Configuration | System filter | Turn-off ramp | Rx offset | Noise | Noise floor |
# |---|---|---|---|---|---|
# | 200×200 m central | WalkTEM cascade LP, 300 kHz | 0.4 ms | — | 3 % | $10^{-11}\,t^{-0.5}$ |
# | 50×50 m central | 2nd-order Butterworth LP, 100 kHz | 0.2 ms | — | 3 % | $10^{-11}\,t^{-0.5}$ |
# | 3×3 m offset | 1st-order Butterworth LP, 30 kHz | 0.3 ms | 10 m | 1 % | $10^{-13}\,t^{-0.5}$ |
#
# The step response is first computed at a dense time grid, then convolved with the piecewise-linear waveform using `convolve_waveform`. The same filter and waveform are passed to `invert()` so the forward model inside the inversion exactly reproduces the observed data.

# %%
import time

rng = np.random.default_rng(42)

# Each config: (label, L, geom_sq, geom_circ, rx, n_quad,
#               times_inv, noise_frac, noise_floor_amp)
config_specs = [
    ('200×200 m central', 200.0, 'square_central', 'circle_central', None, 5,
     np.logspace(-5, -2, 31), 0.02, 1e-13),
    ('50×50 m central', 50.0, 'square_central', 'circle_central', None, 5,
     np.logspace(-5, -2, 31), 0.02, 1e-13),
    ('3×3 m offset', 3.0, 'square_offset', 'circle_offset', 10.0, 11,
     np.logspace(-5, -2, 31), 0.02, 1e-13),
]

_fwd_kw = dict(transform='dlf', hankel_filter='key_101', fourier_filter='key_81')

t0 = time.perf_counter()
configs = {}
for spec in config_specs:
    label, L, geom_sq, geom_circ, rx, nq, times_inv, noise_frac, noise_floor_amp = spec
    kw = dict(**_fwd_kw)

    if rx is None:
        d_clean = -fwd_square_central(thick_true, rho_true, L, times_inv, n_quad=nq, **kw)
    else:
        d_clean = -fwd_square_offset(thick_true, rho_true, L, rx, 0.0, times_inv, n_quad=nq, **kw)

    L_circ      = L / np.sqrt(np.pi)
    noise_floor = noise_floor_amp * times_inv ** (-0.5)
    noise_std   = np.maximum(noise_frac * np.abs(d_clean), noise_floor)
    d_obs       = d_clean + noise_std * rng.standard_normal(len(d_clean))

    print(f'{label}: {len(times_inv)} gates  '
          f'({times_inv[0]*1e3:.2f} ms – {times_inv[-1]*1e3:.1f} ms)  '
          f'noise={noise_frac*100:.0f}%')
    configs[label] = dict(
        L=L, L_circ=L_circ,
        geom_sq=geom_sq, geom_circ=geom_circ,
        rx=rx, n_quad=nq, sys_filt=None,
        d_clean=d_clean, times_inv=times_inv,
        d_obs_inv=d_obs, noise_std_inv=noise_std,
    )
print(f'\n3 configs built in {time.perf_counter()-t0:.2f} s')

fig, ax = plt.subplots(1, 1, figsize=(5, 4))
for (label, cfg), c in zip(configs.items(), ['C0', 'C1', 'C2']):
    ax.loglog(cfg['times_inv'], np.abs(cfg['d_clean']),   '-', color=c, lw=1.5)
    ax.loglog(cfg['times_inv'], np.abs(cfg['d_obs_inv']), '.', color=c, ms=5, label=label)
ax.set_xlabel('Time [s]')
ax.set_ylabel(r'$-dB_z/dt$ [V/m²]')
ax.legend()
ax.grid(True, which='both', alpha=0.5)
fig.tight_layout()
plt.show()
# Out:
# 200×200 m central: 31 gates  (0.01 ms – 10.0 ms)  noise=2%
# 50×50 m central: 31 gates  (0.01 ms – 10.0 ms)  noise=2%
# 3×3 m offset: 31 gates  (0.01 ms – 10.0 ms)  noise=2%
#
# 3 configs built in 12.37 s

# %% [markdown]
# ### 2.2 Inversion: square vs equivalent-area circle
#
# Each dataset is inverted twice, starting from a homogeneous 10 Ohm.m half-space:
#
# 1. **Square forward model** — uses the exact square-loop kernel with Gauss-Legendre quadrature over the loop sides.
# 2. **Equivalent-area circle** — replaces the square loop with a circle of equal area ($r = L / \sqrt{\pi}$), which requires only a 1-D Hankel transform and is significantly faster.
#
# Using a circular approximation is common in practice because it greatly reduces computation time while introducing only a small systematic bias, particularly for large loops relative to the skin depth. The bias grows as the loop size shrinks relative to the target depth or as the offset geometry becomes more asymmetric.

# %%
import time

# Inversion mesh: 15 layers, log-spaced depth axis down to 200 m.
# Package convention: N resistivities, N-1 finite thicknesses (last layer = half-space).
n_layers   = 15
depths_inv = np.geomspace(2.0, 200.0, n_layers)
thick_inv  = np.diff(depths_inv)                  # N-1 = 14 finite thicknesses

# Starting model: homogeneous 100 Ohm.m
rho_start  = np.ones(n_layers) * 10.0
lrho_start = np.log(rho_start)

results_sq   = {}
results_circ = {}
timings      = {}

for label, cfg in configs.items():
    rx_kw = dict(rx_x=cfg['rx']) if cfg['rx'] is not None else {}
    timings[label] = {}

    common_kw = dict(
        thicknesses       = thick_inv,
        log_resistivities = lrho_start,
        times             = cfg['times_inv'],
        noise_std         = cfg['noise_std_inv'],
        max_noise_frac    = 0.0,
        alpha_start       = None,
        alpha_steps       = 10,
        alpha_step        = 3/9,
        maxit             = 15,
        transform         = 'euler',
        hankel_filter     = 'key_101',
        fourier_filter    = 'key_81',
        use_numba         = HAS_NUMBA,
        use_cuda          = HAS_CUDA,
        calc_sens         = False,
        analytical_j      = True,
        **rx_kw,
    )

    # --- Square inversion (correct geometry) ---
    print(f'[Square]  {label}  (geometry={cfg["geom_sq"]}, L={cfg["L"]:.1f} m) ...')
    t0 = time.perf_counter()
    res = invert(
        obs_data  = cfg['d_obs_inv'],
        tx_size   = cfg['L'],
        geometry  = cfg['geom_sq'],
        n_quad    = cfg['n_quad'],
        **common_kw,
    )
    timings[label]['sq'] = time.perf_counter() - t0
    results_sq[label] = res
    print(f"  Final RMS = {res['rms_history'][-1]:.3f}  ({timings[label]['sq']:.1f} s)\n")

    # --- Circle inversion (equivalent-area approximation) ---
    print(f'[Circle]  {label}  (geometry={cfg["geom_circ"]}, r={cfg["L_circ"]:.2f} m) ...')
    t0 = time.perf_counter()
    res = invert(
        obs_data  = cfg['d_obs_inv'],
        tx_size   = cfg['L_circ'],
        geometry  = cfg['geom_circ'],
        n_quad    = 1,
        **common_kw,
    )
    timings[label]['circ'] = time.perf_counter() - t0
    results_circ[label] = res
    print(f"  Final RMS = {res['rms_history'][-1]:.3f}  ({timings[label]['circ']:.1f} s)\n")

# --- Timing summary ---
print(f"\n{'Config':<22}  {'Square':>10}  {'Iters':>6}  {'Circle':>10}  {'Iters':>6}")
print('-' * 60)
for label in configs:
    n_sq   = len(results_sq[label]['rms_history'])
    n_circ = len(results_circ[label]['rms_history'])
    print(f"{label:<22}  {timings[label]['sq']:>9.1f} s  {n_sq:>6d}  "
          f"{timings[label]['circ']:>9.1f} s  {n_circ:>6d}")
# Out:
# [Square]  200×200 m central  (geometry=square_central, L=200.0 m) ...
# Observed data: Mean Apparent Resistivity = 154.1 Ohm.m (over 31/31 valid gates)
# WARNING: 2 non-positive dbdt values (zeroed in J)
# Alpha start = 13357.312
# Iteration   1:  RMS = 76.22
#     Alpha = 13357.31,  RMS = 20.86
#     Alpha = 6199.92,  RMS = 19.93
#     Alpha = 2877.75,  RMS = 19.31
#     Alpha = 1335.73,  RMS = 19.04
#     Alpha = 619.99,  RMS = 19.30
#     RMS increased - stopping alpha search early.
# Iteration   2:  RMS = 19.04
# WARNING: 1 non-positive dbdt values (zeroed in J)
#     Alpha = 2877.75,  RMS = 16.56
#     Alpha = 1335.73,  RMS = 16.37
#     Alpha = 619.99,  RMS = 16.43
#     RMS increased - stopping alpha search early.
# Iteration   3:  RMS = 16.37
#     Alpha = 2877.75,  RMS = 10.74
#     Alpha = 1335.73,  RMS = 10.66
#     Alpha = 619.99,  RMS = 10.65
#     Alpha = 287.77,  RMS = 11.01
#     RMS increased - stopping alpha search early.
# Iteration   4:  RMS = 10.65
#     Alpha = 1335.73,  RMS = 7.73
#     Alpha = 619.99,  RMS = 8.02
#     RMS increased - stopping alpha search early.
# Iteration   5:  RMS = 7.73
#     Alpha = 2877.75,  RMS = 6.81
#     Alpha = 1335.73,  RMS = 5.41
#     Alpha = 619.99,  RMS = 5.41
#     RMS increased - stopping alpha search early.
# Iteration   6:  RMS = 5.41
#     Alpha = 2877.75,  RMS = 6.79
#     Alpha = 1335.73,  RMS = 4.53
#     Alpha = 619.99,  RMS = 3.35
#     Alpha = 287.77,  RMS = 3.79
#     RMS increased - stopping alpha search early.
# Iteration   7:  RMS = 3.35
#     Alpha = 1335.73,  RMS = 4.45
#     Alpha = 619.99,  RMS = 2.56
#     Alpha = 287.77,  RMS = 1.79
#     Alpha = 133.57,  RMS = 2.24
#     RMS increased - stopping alpha search early.
# Iteration   8:  RMS = 1.79
#     Alpha = 619.99,  RMS = 2.40
#     Alpha = 287.77,  RMS = 1.43
#     Alpha = 133.57,  RMS = 1.05
#     Alpha = 62.00,  RMS = 1.21
#     RMS increased - stopping alpha search early.
# Iteration   9:  RMS = 1.05
#     Alpha = 287.77,  RMS = 1.43
#     Alpha = 133.57,  RMS = 1.00
#     RMS below 1 - stopping for parabola fit.
#     Fitted Alpha = 134.059, Actual RMS = 0.999
#   Final RMS = 0.999  (73.1 s)
#
# [Circle]  200×200 m central  (geometry=circle_central, r=112.84 m) ...
# Observed data: Mean Apparent Resistivity = 154.1 Ohm.m (over 31/31 valid gates)
# Alpha start = 13413.274
# Iteration   1:  RMS = 74.81
#     Alpha = 13413.27,  RMS = 20.21
#     Alpha = 6225.89,  RMS = 16.94
#     Alpha = 2889.80,  RMS = 14.47
#     Alpha = 1341.33,  RMS = 13.55
#     Alpha = 622.59,  RMS = 14.54
#     RMS increased - stopping alpha search early.
# Iteration   2:  RMS = 13.55
#     Alpha = 2889.80,  RMS = 13.17
#     Alpha = 1341.33,  RMS = 14.69
#     RMS increased - stopping alpha search early.
# Iteration   3:  RMS = 13.17
#     Alpha = 6225.89,  RMS = 8.13
#     Alpha = 2889.80,  RMS = 6.10
#     Alpha = 1341.33,  RMS = 5.05
#     Alpha = 622.59,  RMS = 5.14
#     RMS increased - stopping alpha search early.
# Iteration   4:  RMS = 5.05
#     Alpha = 2889.80,  RMS = 6.55
#     Alpha = 1341.33,  RMS = 4.23
#     Alpha = 622.59,  RMS = 3.06
#     Alpha = 288.98,  RMS = 3.44
#     RMS increased - stopping alpha search early.
# Iteration   5:  RMS = 3.06
#     Alpha = 1341.33,  RMS = 4.13
#     Alpha = 622.59,  RMS = 2.39
#     Alpha = 288.98,  RMS = 1.63
#     Alpha = 134.13,  RMS = 1.98
#     RMS increased - stopping alpha search early.
# Iteration   6:  RMS = 1.63
#     Alpha = 622.59,  RMS = 2.27
#     Alpha = 288.98,  RMS = 1.39
#     Alpha = 134.13,  RMS = 1.02
#     Alpha = 62.26,  RMS = 1.10
#     RMS increased - stopping alpha search early.
# Iteration   7:  RMS = 1.02
#     Alpha = 288.98,  RMS = 1.40
#     Alpha = 134.13,  RMS = 1.00
#     RMS below 1 - stopping for parabola fit.
#     Fitted Alpha = 134.170, Actual RMS = 1.000
#   Final RMS = 1.000  (3.8 s)
#
# [Square]  50×50 m central  (geometry=square_central, L=50.0 m) ...
# Observed data: Mean Apparent Resistivity = 44.0 Ohm.m (over 31/31 valid gates)
# Alpha start = 11213.039
# Iteration   1:  RMS = 74.08
#     Alpha = 11213.04,  RMS = 24.61
#     Alpha = 5204.63,  RMS = 26.85
#     RMS increased - stopping alpha search early.
# Iteration   2:  RMS = 24.61
#     Alpha = 24157.76,  RMS = 18.26
#     Alpha = 11213.04,  RMS = 14.62
#     Alpha = 5204.63,  RMS = 14.61
#     Alpha = 2415.78,  RMS = 15.83
#     RMS increased - stopping alpha search early.
# Iteration   3:  RMS = 14.61
#     Alpha = 11213.04,  RMS = 12.29
#     Alpha = 5204.63,  RMS = 6.57
#     Alpha = 2415.78,  RMS = 3.61
#     Alpha = 1121.30,  RMS = 2.57
#     Alpha = 520.46,  RMS = 2.35
#     Alpha = 241.58,  RMS = 2.49
#     RMS increased - stopping alpha search early.
# Iteration   4:  RMS = 2.35
#     Alpha = 1121.30,  RMS = 3.09
#     Alpha = 520.46,  RMS = 2.01
#     Alpha = 241.58,  RMS = 1.48
#     Alpha = 112.13,  RMS = 1.21
#     Alpha = 52.05,  RMS = 1.34
#     RMS increased - stopping alpha search early.
# Iteration   5:  RMS = 1.21
#     Alpha = 241.58,  RMS = 1.63
#     Alpha = 112.13,  RMS = 1.24
#     Alpha = 52.05,  RMS = 1.02
#     Alpha = 24.16,  RMS = 1.20
#     RMS increased - stopping alpha search early.
# Iteration   6:  RMS = 1.02
#     Alpha = 112.13,  RMS = 1.42
#     Alpha = 52.05,  RMS = 1.03
#     Alpha = 24.16,  RMS = 0.89
#     RMS below 1 - stopping for parabola fit.
#     Fitted Alpha = 47.388, Actual RMS = 1.002
#   Final RMS = 1.002  (68.9 s)
#
# [Circle]  50×50 m central  (geometry=circle_central, r=28.21 m) ...
# Observed data: Mean Apparent Resistivity = 44.0 Ohm.m (over 31/31 valid gates)
# Alpha start = 11241.119
# Iteration   1:  RMS = 74.39
#     Alpha = 11241.12,  RMS = 25.02
#     Alpha = 5217.67,  RMS = 27.39
#     RMS increased - stopping alpha search early.
# Iteration   2:  RMS = 25.02
#     Alpha = 24218.26,  RMS = 18.45
#     Alpha = 11241.12,  RMS = 14.88
#     Alpha = 5217.67,  RMS = 14.96
#     RMS increased - stopping alpha search early.
# Iteration   3:  RMS = 14.88
#     Alpha = 24218.26,  RMS = 16.30
#     Alpha = 11241.12,  RMS = 9.90
#     Alpha = 5217.67,  RMS = 5.85
#     Alpha = 2421.83,  RMS = 4.14
#     Alpha = 1124.11,  RMS = 3.89
#     Alpha = 521.77,  RMS = 4.06
#     RMS increased - stopping alpha search early.
# Iteration   4:  RMS = 3.89
#     Alpha = 2421.83,  RMS = 4.32
#     Alpha = 1124.11,  RMS = 2.55
#     Alpha = 521.77,  RMS = 1.77
#     Alpha = 242.18,  RMS = 1.42
#     Alpha = 112.41,  RMS = 1.34
#     Alpha = 52.18,  RMS = 1.76
#     RMS increased - stopping alpha search early.
# Iteration   5:  RMS = 1.34
#     Alpha = 242.18,  RMS = 1.74
#     Alpha = 112.41,  RMS = 1.25
#     Alpha = 52.18,  RMS = 1.02
#     Alpha = 24.22,  RMS = 1.07
#     RMS increased - stopping alpha search early.
# Iteration   6:  RMS = 1.02
#     Alpha = 112.41,  RMS = 1.44
#     Alpha = 52.18,  RMS = 1.04
#     Alpha = 24.22,  RMS = 0.90
#     RMS below 1 - stopping for parabola fit.
#     Fitted Alpha = 46.308, Actual RMS = 1.005
#   Final RMS = 1.005  (4.2 s)
#
# [Square]  3×3 m offset  (geometry=square_offset, L=3.0 m) ...
# Observed data: Mean Apparent Resistivity = 33.1 Ohm.m (over 29/31 valid gates)
# C:\Users\pamcl\OneDrive - Danmarks Tekniske Universitet\Dokumenter\Projects\Python\pyTEM\pytem\inversion.py:440: RuntimeWarning: invalid value encountered in power
#   app_rho = (MU0 / (4 * np.pi * times)) * (term ** (2 / 3))
# Alpha start = 15863.705
# Iteration   1:  RMS = 66.73
#     Alpha = 15863.70,  RMS = 24.77
#     Alpha = 7363.28,  RMS = 27.37
#     RMS increased - stopping alpha search early.
# Iteration   2:  RMS = 24.77
#     Alpha = 34177.32,  RMS = 15.55
#     Alpha = 15863.70,  RMS = 11.37
#     Alpha = 7363.28,  RMS = 8.85
#     Alpha = 3417.73,  RMS = 8.20
#     Alpha = 1586.37,  RMS = 8.67
#     RMS increased - stopping alpha search early.
# Iteration   3:  RMS = 8.20
#     Alpha = 7363.28,  RMS = 8.63
#     Alpha = 3417.73,  RMS = 4.99
#     Alpha = 1586.37,  RMS = 2.93
#     Alpha = 736.33,  RMS = 2.07
#     Alpha = 341.77,  RMS = 1.72
#     Alpha = 158.64,  RMS = 1.58
#     Alpha = 73.63,  RMS = 1.70
#     RMS increased - stopping alpha search early.
# Iteration   4:  RMS = 1.58
#     Alpha = 341.77,  RMS = 2.20
#     Alpha = 158.64,  RMS = 1.48
#     Alpha = 73.63,  RMS = 1.12
#     Alpha = 34.18,  RMS = 0.94
#     RMS below 1 - stopping for parabola fit.
#     Fitted Alpha = 53.348, Actual RMS = 1.019
#   Final RMS = 1.019  (416.9 s)
#
# [Circle]  3×3 m offset  (geometry=circle_offset, r=1.69 m) ...
# Observed data: Mean Apparent Resistivity = 33.1 Ohm.m (over 29/31 valid gates)
# Alpha start = 15865.350
# Iteration   1:  RMS = 66.74
#     Alpha = 15865.35,  RMS = 24.77
#     Alpha = 7364.04,  RMS = 27.37
#     RMS increased - stopping alpha search early.
# Iteration   2:  RMS = 24.77
#     Alpha = 34180.86,  RMS = 15.55
#     Alpha = 15865.35,  RMS = 11.37
#     Alpha = 7364.04,  RMS = 8.85
#     Alpha = 3418.09,  RMS = 8.20
#     Alpha = 1586.53,  RMS = 8.67
#     RMS increased - stopping alpha search early.
# Iteration   3:  RMS = 8.20
#     Alpha = 7364.04,  RMS = 8.64
#     Alpha = 3418.09,  RMS = 4.99
#     Alpha = 1586.53,  RMS = 2.93
#     Alpha = 736.40,  RMS = 2.07
#     Alpha = 341.81,  RMS = 1.72
#     Alpha = 158.65,  RMS = 1.58
#     Alpha = 73.64,  RMS = 1.70
#     RMS increased - stopping alpha search early.
# Iteration   4:  RMS = 1.58
#     Alpha = 341.81,  RMS = 2.20
#     Alpha = 158.65,  RMS = 1.48
#     Alpha = 73.64,  RMS = 1.12
#     Alpha = 34.18,  RMS = 0.94
#     RMS below 1 - stopping for parabola fit.
#     Fitted Alpha = 53.311, Actual RMS = 1.019
#   Final RMS = 1.019  (3.8 s)
#
#
# Config                      Square   Iters      Circle   Iters
# ------------------------------------------------------------
# 200×200 m central            73.1 s      10        3.8 s       8
# 50×50 m central              68.9 s       7        4.2 s       7
# 3×3 m offset                416.9 s       5        3.8 s       5

# %% [markdown]
# ### 2.3 Recovery: data fit and model comparison
#
# The 3×3 figure below shows, for each configuration:
# - **Row 1:** Data fit — observed data (black dots) overlaid with predictions from the square and circle inversions.
# - **Row 2:** Model recovery — inverted resistivity profiles against the true model (dashed black).
# - **Row 3:** Model difference — relative difference $(\rho_\text{circ} - \rho_\text{sq}) / \rho_\text{sq}$ [%], quantifying the bias introduced by the circular approximation.

# %%
# True model step function
deps_t = np.concatenate(([0], np.cumsum(thick_true), [depths_inv[-1]]))
rho_t  = np.concatenate([np.repeat(rho_true[:-1], 2), [rho_true[-1], rho_true[-1]]])
dep_t  = np.repeat(deps_t, 2)[1:-1]

def make_dpred(cfg, res, geom, L, nq):
    thick_r   = res['thicknesses']
    rho_inv   = res['resistivities']
    t         = cfg['times_inv']
    kw        = dict(transform='dlf', hankel_filter='key_101', fourier_filter='key_81')
    if geom == 'circle_central':
        return -fwd_circle_central(thick_r, rho_inv, L, t, **kw)
    elif geom == 'circle_offset':
        return -fwd_circle_offset(thick_r, rho_inv, L, cfg['rx'], t, **kw)
    elif geom == 'square_central':
        return -fwd_square_central(thick_r, rho_inv, L, t, n_quad=nq, **kw)
    else:
        return -fwd_square_offset(thick_r, rho_inv, L, cfg['rx'], 0.0, t, n_quad=nq, **kw)

depth_mids = np.concatenate(([0], np.cumsum(thick_inv)))

fig, axs = plt.subplots(3, 3, figsize=(13, 10),
                        gridspec_kw={'height_ratios': [1, 1, 1]},
                        sharey='row', sharex='row')

for j, (label, cfg) in enumerate(configs.items()):
    res_sq   = results_sq[label]
    res_circ = results_circ[label]

    inv_times   = cfg['times_inv']
    obs_trimmed = cfg['d_obs_inv']

    d_pred_sq   = make_dpred(cfg, res_sq,   cfg['geom_sq'],   cfg['L'],      cfg['n_quad'])
    d_pred_circ = make_dpred(cfg, res_circ, cfg['geom_circ'], cfg['L_circ'], 1)

    # --- Row 0: Data misfit ---
    ax = axs[0, j]
    ax.loglog(inv_times, obs_trimmed, 'o',  ms=4, color='k',  label='Observed', zorder=3)
    ax.loglog(inv_times, d_pred_sq,   '-',  lw=2, color='C0', label=f"Square FWD (RMS={res_sq['rms_history'][-1]:.2f})")
    ax.loglog(inv_times, d_pred_circ, '-',  lw=2, color='C1', label=f"Circle FWD (RMS={res_circ['rms_history'][-1]:.2f})")
    ax.set_title(label)
    ax.set_xlabel('Time [s]')
    ax.legend(fontsize=8)
    ax.grid(True, which='both', alpha=0.3)

    # --- Row 1: Model recovery ---
    ax = axs[1, j]
    for res, color, tag in [(res_sq, 'C0', 'Square FWD'), (res_circ, 'C1', 'Circle FWD')]:
        thick_r  = res['thicknesses']
        rho_inv  = res['resistivities']
        depths_r = np.concatenate(([0], np.cumsum(thick_r)))
        rho_step = np.repeat(rho_inv, 2)
        dep_step = np.repeat(np.append(depths_r, depths_inv[-1]), 2)[1:-1]
        ax.semilogx(rho_step, dep_step, '-', lw=2, color=color, label=tag)
    ax.semilogx(rho_t, dep_t, '--', lw=1.5, color='k', label='True')
    ax.legend(fontsize=8)
    ax.grid(True, which='both', alpha=0.3)
    ax.set_xlabel('Resistivity [Ohm.m]')

    # --- Row 2: Model difference (%) ---
    rho_sq_inv   = res_sq['resistivities']
    rho_circ_inv = res_circ['resistivities']
    delta_pct    = (rho_circ_inv - rho_sq_inv) / rho_sq_inv * 100.0
    dep_step     = np.repeat(np.append(depth_mids, depths_inv[-1]), 2)[1:-1]
    delta_step   = np.repeat(delta_pct, 2)

    ax = axs[2, j]
    ax.plot(delta_step, dep_step, '-', lw=2, color='C2')
    ax.axvline(0, color='k', lw=0.8, ls='--')
    ax.set_xlabel(r'Difference [%]')
    ax.grid(True, which='both', alpha=0.3)

# Invert depth axes once — calling invert_yaxis() inside the column loop
# toggles the shared axis each time (sharey='row'), which flips the result
# when the number of configs is even.
axs[1, 0].invert_yaxis()
axs[2, 0].invert_yaxis()

axs[0, 0].set_ylabel(r'$-dB_z/dt$ [V/m²]')
axs[1, 0].set_ylabel('Depth [m]')
axs[2, 0].set_ylabel('Depth [m]')
fig.tight_layout()
plt.show()

# %% [markdown]
# ### 2.4 Circle warm-start
#
# For square-loop geometries the forward model is significantly more expensive than the equivalent-area circle (Gauss-Legendre quadrature over the loop sides vs a single Hankel transform).  The `circle_warmstart=True` flag exploits this by:
#
# 1. Running the full Gauss-Newton inversion with the circle model until convergence.
# 2. Taking the converged model as a starting point and doing **one** refinement step with the exact square forward model.
#
# This gives a result very close to a pure square inversion at a fraction of the cost.  The example below runs all three configurations with `circle_warmstart=True` and compares the timing and final RMS against the pure square result.

# %%
import time
results_ws = {}
timings_ws = {}

for label, cfg in configs.items():
    if not cfg['geom_sq'].startswith('square'):
        continue
    rx_kw = dict(rx_x=cfg['rx']) if cfg['rx'] is not None else {}

    t0 = time.perf_counter()
    res = invert(
        obs_data          = cfg['d_obs_inv'],
        thicknesses       = thick_inv,
        log_resistivities = lrho_start,
        tx_size           = cfg['L'],
        times             = cfg['times_inv'],
        noise_std         = cfg['noise_std_inv'],
        max_noise_frac    = 0.0,
        alpha_start       = None,
        alpha_steps       = 10,
        maxit             = 15,
        transform         = 'euler',
        hankel_filter     = 'key_101',
        fourier_filter    = 'key_81',
        use_numba         = HAS_NUMBA,
        use_cuda          = HAS_CUDA,
        calc_sens         = False,
        analytical_j      = True,
        geometry          = cfg['geom_sq'],
        n_quad            = cfg['n_quad'],
        circle_warmstart  = True,
        **rx_kw,
    )
    timings_ws[label] = time.perf_counter() - t0
    results_ws[label] = res

# --- Comparison table ---
print(f"\n{'Config':<22}  {'Square (pure)':>14}  {'Warm-start':>12}  {'ΔRMS':>8}")
print('-' * 65)
for label in results_ws:
    rms_sq = results_sq[label]['rms_history'][-1]
    rms_ws = results_ws[label]['rms_history'][-1]
    t_sq   = timings[label]['sq']
    t_ws   = timings_ws[label]
    print(f"{label:<22}  {t_sq:>9.1f} s  {rms_sq:>5.3f}  "
          f"{t_ws:>7.1f} s  {rms_ws:>5.3f}  {rms_ws - rms_sq:>+8.4f}")
# Out:
# [circle_warmstart] Running circle pre-inversion (geometry=circle_central, r=112.838 m)...
# Observed data: Mean Apparent Resistivity = 154.1 Ohm.m (over 31/31 valid gates)
# Alpha start = 13413.274
# Iteration   1:  RMS = 74.81
#     Alpha = 13413.27,  RMS = 20.21
#     Alpha = 10385.41,  RMS = 19.08
#     Alpha = 8041.05,  RMS = 17.98
#     Alpha = 6225.89,  RMS = 16.94
#     Alpha = 4820.48,  RMS = 15.99
#     Alpha = 3732.32,  RMS = 15.15
#     Alpha = 2889.80,  RMS = 14.47
#     Alpha = 2237.47,  RMS = 13.96
#     Alpha = 1732.39,  RMS = 13.65
#     Alpha = 1341.33,  RMS = 13.55
# Iteration   2:  RMS = 13.55
#     Alpha = 1732.39,  RMS = 14.01
#     Alpha = 1341.33,  RMS = 14.69
#     Alpha = 1038.54,  RMS = 15.52
#     Alpha = 804.10,  RMS = 16.48
#     Alpha = 622.59,  RMS = 17.51
#     Alpha = 482.05,  RMS = 18.57
#     Alpha = 373.23,  RMS = 19.61
#     Alpha = 288.98,  RMS = 20.62
#     Alpha = 223.75,  RMS = 21.59
#     Alpha = 173.24,  RMS = 22.50
#   No improvement found - stopping.
# [circle_warmstart] Circle converged (RMS=13.550). Running up to 15 square refinement steps...
# Observed data: Mean Apparent Resistivity = 154.1 Ohm.m (over 31/31 valid gates)
# Alpha start = 2251.201
# Iteration   1:  RMS = 13.70
#     Alpha = 2251.20,  RMS = 11.35
#     Alpha = 1743.02,  RMS = 11.22
#     Alpha = 1349.56,  RMS = 11.14
#     Alpha = 1044.92,  RMS = 11.12
#     Alpha = 809.04,  RMS = 11.18
#     RMS increased - stopping alpha search early.
# Iteration   2:  RMS = 11.12
#     Alpha = 1349.56,  RMS = 5.16
#     Alpha = 1044.92,  RMS = 4.90
#     Alpha = 809.04,  RMS = 4.85
#     Alpha = 626.41,  RMS = 4.98
#     RMS increased - stopping alpha search early.
# Iteration   3:  RMS = 4.85
#     Alpha = 1044.92,  RMS = 4.01
#     Alpha = 809.04,  RMS = 3.38
#     Alpha = 626.41,  RMS = 2.96
#     Alpha = 485.01,  RMS = 2.81
#     Alpha = 375.52,  RMS = 2.90
#     RMS increased - stopping alpha search early.
# Iteration   4:  RMS = 2.81
#     Alpha = 626.41,  RMS = 2.46
#     Alpha = 485.01,  RMS = 2.05
#     Alpha = 375.52,  RMS = 1.73
#     Alpha = 290.75,  RMS = 1.52
#     Alpha = 225.12,  RMS = 1.44
#     Alpha = 174.30,  RMS = 1.49
#     RMS increased - stopping alpha search early.
# Iteration   5:  RMS = 1.44
#     Alpha = 290.75,  RMS = 1.42
#     Alpha = 225.12,  RMS = 1.24
#     Alpha = 174.30,  RMS = 1.10
#     Alpha = 134.96,  RMS = 1.00
#     Alpha = 104.49,  RMS = 0.94
#     RMS below 1 - stopping for parabola fit.
#     Fitted Alpha = 135.207, Actual RMS = 1.001
# [circle_warmstart] Running circle pre-inversion (geometry=circle_central, r=28.209 m)...
# Observed data: Mean Apparent Resistivity = 44.0 Ohm.m (over 31/31 valid gates)
# Alpha start = 11241.119
# Iteration   1:  RMS = 74.39
#     Alpha = 11241.12,  RMS = 25.02
#     Alpha = 8703.59,  RMS = 25.39
#     RMS increased - stopping alpha search early.
# Iteration   2:  RMS = 25.02
#     Alpha = 14518.46,  RMS = 15.60
#     Alpha = 11241.12,  RMS = 14.88
#     Alpha = 8703.59,  RMS = 14.60
#     Alpha = 6738.87,  RMS = 14.67
#     RMS increased - stopping alpha search early.
# Iteration   3:  RMS = 14.60
#     Alpha = 11241.12,  RMS = 10.50
#     Alpha = 8703.59,  RMS = 8.68
#     Alpha = 6738.87,  RMS = 7.15
#     Alpha = 5217.67,  RMS = 5.90
#     Alpha = 4039.85,  RMS = 4.93
#     Alpha = 3127.91,  RMS = 4.21
#     Alpha = 2421.83,  RMS = 3.72
#     Alpha = 1875.13,  RMS = 3.43
#     Alpha = 1451.85,  RMS = 3.26
#     Alpha = 1124.11,  RMS = 3.19
# Iteration   4:  RMS = 3.19
#     Alpha = 1451.85,  RMS = 3.00
#     Alpha = 1124.11,  RMS = 2.55
#     Alpha = 870.36,  RMS = 2.22
#     Alpha = 673.89,  RMS = 1.96
#     Alpha = 521.77,  RMS = 1.77
#     Alpha = 403.98,  RMS = 1.62
#     Alpha = 312.79,  RMS = 1.51
#     Alpha = 242.18,  RMS = 1.42
#     Alpha = 187.51,  RMS = 1.35
#     Alpha = 145.18,  RMS = 1.32
# Iteration   5:  RMS = 1.32
#     Alpha = 187.51,  RMS = 1.44
#     Alpha = 145.18,  RMS = 1.32
#     Alpha = 112.41,  RMS = 1.23
#     Alpha = 87.04,  RMS = 1.15
#     Alpha = 67.39,  RMS = 1.08
#     Alpha = 52.18,  RMS = 1.04
#     Alpha = 40.40,  RMS = 1.07
#     RMS increased - stopping alpha search early.
# Iteration   6:  RMS = 1.04
#     Alpha = 67.39,  RMS = 1.13
#     Alpha = 52.18,  RMS = 1.04
#     Alpha = 40.40,  RMS = 0.97
#     RMS below 1 - stopping for parabola fit.
#     Fitted Alpha = 45.671, Actual RMS = 1.001
# [circle_warmstart] Circle converged (RMS=1.001). Running up to 15 square refinement steps...
# Observed data: Mean Apparent Resistivity = 44.0 Ohm.m (over 31/31 valid gates)
# Alpha start = 91.187
# Iteration   1:  RMS = 1.02
#     Alpha = 91.19,  RMS = 1.30
#     Alpha = 70.60,  RMS = 1.16
#     Alpha = 54.67,  RMS = 1.06
#     Alpha = 42.33,  RMS = 0.98
#     RMS below 1 - stopping for parabola fit.
#     Fitted Alpha = 46.136, Actual RMS = 1.004
# [circle_warmstart] Running circle pre-inversion (geometry=circle_offset, r=1.693 m)...
# Observed data: Mean Apparent Resistivity = 33.1 Ohm.m (over 29/31 valid gates)
# Alpha start = 15865.350
# Iteration   1:  RMS = 66.74
#     Alpha = 15865.35,  RMS = 24.77
#     Alpha = 12283.96,  RMS = 25.48
#     RMS increased - stopping alpha search early.
# Iteration   2:  RMS = 24.77
#     Alpha = 20490.89,  RMS = 12.60
#     Alpha = 15865.35,  RMS = 11.37
#     Alpha = 12283.96,  RMS = 10.32
#     Alpha = 9511.03,  RMS = 9.48
#     Alpha = 7364.04,  RMS = 8.85
#     Alpha = 5701.71,  RMS = 8.44
#     Alpha = 4414.63,  RMS = 8.24
#     Alpha = 3418.09,  RMS = 8.20
#     Alpha = 2646.50,  RMS = 8.30
#     RMS increased - stopping alpha search early.
# Iteration   3:  RMS = 8.20
#     Alpha = 4414.63,  RMS = 6.02
#     Alpha = 3418.09,  RMS = 4.99
#     Alpha = 2646.50,  RMS = 4.14
#     Alpha = 2049.09,  RMS = 3.46
#     Alpha = 1586.53,  RMS = 2.93
#     Alpha = 1228.40,  RMS = 2.55
#     Alpha = 951.10,  RMS = 2.27
#     Alpha = 736.40,  RMS = 2.07
#     Alpha = 570.17,  RMS = 1.92
#     Alpha = 441.46,  RMS = 1.81
# Iteration   4:  RMS = 1.81
#     Alpha = 570.17,  RMS = 2.08
#     Alpha = 441.46,  RMS = 1.86
#     Alpha = 341.81,  RMS = 1.69
#     Alpha = 264.65,  RMS = 1.55
#     Alpha = 204.91,  RMS = 1.43
#     Alpha = 158.65,  RMS = 1.34
#     Alpha = 122.84,  RMS = 1.25
#     Alpha = 95.11,  RMS = 1.18
#     Alpha = 73.64,  RMS = 1.13
#     Alpha = 57.02,  RMS = 1.13
# Iteration   5:  RMS = 1.13
#     Alpha = 73.64,  RMS = 1.22
#     Alpha = 57.02,  RMS = 1.11
#     Alpha = 44.15,  RMS = 1.02
#     Alpha = 34.18,  RMS = 0.94
#     RMS below 1 - stopping for parabola fit.
#     Fitted Alpha = 42.134, Actual RMS = 1.001
# [circle_warmstart] Circle converged (RMS=1.001). Running up to 15 square refinement steps...
# Observed data: Mean Apparent Resistivity = 33.1 Ohm.m (over 29/31 valid gates)
# Alpha start = 12.590
# Iteration   1:  RMS = 1.00
#     Alpha = 12.59,  RMS = 0.87
#     RMS below 1 - stopping for parabola fit.
#
# Config                   Square (pure)    Warm-start      ΔRMS
# -----------------------------------------------------------------
# 200×200 m central            73.1 s  0.999     54.2 s  1.001   +0.0016
# 50×50 m central              68.9 s  1.002     19.3 s  1.004   +0.0023
# 3×3 m offset                416.9 s  1.019     76.1 s  0.868   -0.1504

# %%
# --- Recovery comparison: pure square vs warm-start ---
fig, axs = plt.subplots(1, len(results_ws), figsize=(13, 4), sharey=True)

for j, (label, cfg) in enumerate([item for item in configs.items()
                                   if item[1]['geom_sq'].startswith('square')]):
    res_sq_pure = results_sq[label]
    res_ws_     = results_ws[label]

    thick_r = res_sq_pure['thicknesses']
    depths_r = np.concatenate(([0], np.cumsum(thick_r)))

    ax = axs[j] if len(results_ws) > 1 else axs

    for res, color, tag in [
        (res_sq_pure, 'C0', f"Square (RMS={res_sq_pure['rms_history'][-1]:.3f})"),
        (res_ws_,     'C3', f"Warm-start (RMS={res_ws_['rms_history'][-1]:.3f})"),
    ]:
        rho_inv  = res['resistivities']
        rho_step = np.repeat(rho_inv, 2)
        dep_step = np.repeat(np.append(depths_r, depths_inv[-1]), 2)[1:-1]
        ax.semilogx(rho_step, dep_step, '-', lw=2, color=color, label=tag)

    ax.semilogx(rho_t, dep_t, '--', lw=1.5, color='k', label='True')
    ax.set_title(label)
    ax.set_xlabel('Resistivity [Ohm.m]')
    ax.invert_yaxis()
    ax.legend()
    ax.grid(True, which='both', alpha=0.3)

axs[0].set_ylabel('Depth [m]')
fig.tight_layout()
plt.show()
