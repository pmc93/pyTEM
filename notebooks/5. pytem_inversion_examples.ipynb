# %% [markdown]
# # 3. Inversion Examples
#
# This notebook demonstrates TEM inversion using pyTEM.
# All forward models, Jacobians and inversion utilities are imported directly from the codebase.
#
# Topics covered:
# 1. **Benchmark model**: three-layer synthetic model used throughout.
# 2. **Synthetic inversion**: build noisy data from the true model, then recover it using Gauss-Newton inversion.
#    - 2.1 Build synthetic data (three square-loop configurations)
#    - 2.2 Inversion: correct square forward model vs equivalent-area circle approximation
#    - 2.3 Recovery plots: data fit, model comparison, and model difference

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

sys.path.insert(0, r'C:\Users\pamcl\OneDrive - Danmarks Tekniske Universitet\Dokumenter\Projects\Python\pyTEM')

from pytem import (
    fwd_circle_central,
    fwd_circle_offset,
    fwd_square_central,
    fwd_square_offset,
    getJ_ana,
    getJ_fd,
    getR,
    getRMS,
    invert,
    butterworth_filter,
    cascade_filter,
    convolve_waveform,
    plot_sounding,
    plot_model,
    plot_inversion,
    MU0,
    HAS_NUMBA,
    HAS_CUDA,
    HANKEL_FILTERS,
    FOURIER_FILTERS,
    EULER_PARAMS,
)

print(f'Numba: {HAS_NUMBA},  CUDA: {HAS_CUDA}')
# Out:
# Numba: True,  CUDA: True

# %% [markdown]
# ## 1. Benchmark Model
#
# A simple 3-layer synthetic model is used throughout all examples:
#
# | Layer | Resistivity | Thickness |
# |-------|------------|-----------|
# | Resistive overburden | 100 Ohm.m | 20 m |
# | Conductive target | 10 Ohm.m | 40 m |
# | Resistive basement | 500 Ohm.m | half-space |
#
# Data are computed over 31 log-spaced time gates from 10 µs to 10 ms.
# Three square-loop configurations are used to span a range of loop sizes and receiver offsets.

# %%
# --- True model ---
rho_true    = np.array([100.0, 10.0, 500.0])   # [Ohm.m]
thick_true  = np.array([20.0, 40.0])           # [m]  (2 layers -> 2 thicknesses)

# --- Survey geometry ---
tx_radius   = np.sqrt(40.**2 / np.pi)           # equivalent circular radius for 40 m loop
side_length = 40.0                              # square loop side [m]
rx_offset   = 10.0                              # offset receiver distance [m]

print(f'tx_radius = {tx_radius:.2f} m')
print(f'rho_true  = {rho_true}')
print(f'thick_true = {thick_true}')
# Out:
# tx_radius = 22.57 m
# rho_true  = [100.  10. 500.]
# thick_true = [20. 40.]

# %% [markdown]
# ### 2.1 Build synthetic data
#
# Noise-contaminated synthetic data are generated from the true 3-layer model for each of the three square-loop configurations.
# Gaussian noise is added as a fraction of the signal amplitude, with a noise floor proportional to $t^{-0.5}$.
#
# Each configuration has its own **system filter**, **transmitter waveform**, and **noise level**:
#
# | Configuration | System filter | Turn-off ramp | Rx offset | Noise | Noise floor |
# |---|---|---|---|---|---|
# | 200×200 m central | WalkTEM cascade LP, 300 kHz | 0.4 ms | — | 3 % | $10^{-11}\,t^{-0.5}$ |
# | 50×50 m central | 2nd-order Butterworth LP, 100 kHz | 0.2 ms | — | 3 % | $10^{-11}\,t^{-0.5}$ |
# | 3×3 m offset | 1st-order Butterworth LP, 30 kHz | 0.3 ms | 10 m | 1 % | $10^{-13}\,t^{-0.5}$ |
#
# The step response is first computed at a dense time grid, then convolved with the piecewise-linear waveform using `convolve_waveform`. The same filter and waveform are passed to `invert()` so the forward model inside the inversion exactly reproduces the observed data.

# %%
import time

rng = np.random.default_rng(42)

# Each config: (label, L, geom_sq, geom_circ, rx, n_quad,
#               times_inv, noise_frac, noise_floor_amp)
config_specs = [
    ('200×200 m central', 200.0, 'square_central', 'circle_central', None, 5,
     np.logspace(-5, -2, 31), 0.02, 1e-13),
    ('50×50 m central', 50.0, 'square_central', 'circle_central', None, 5,
     np.logspace(-5, -2, 31), 0.02, 1e-13),
    ('3×3 m offset', 3.0, 'square_offset', 'circle_offset', 10.0, 11,
     np.logspace(-5, -2, 31), 0.02, 1e-13),
]

_fwd_kw = dict(transform='dlf', hankel_filter='key_101', fourier_filter='key_81')

t0 = time.perf_counter()
configs = {}
for spec in config_specs:
    label, L, geom_sq, geom_circ, rx, nq, times_inv, noise_frac, noise_floor_amp = spec
    kw = dict(**_fwd_kw)

    if rx is None:
        d_clean = -fwd_square_central(thick_true, rho_true, L, times_inv, n_quad=nq, **kw)
    else:
        d_clean = -fwd_square_offset(thick_true, rho_true, L, rx, 0.0, times_inv, n_quad=nq, **kw)

    L_circ      = L / np.sqrt(np.pi)
    noise_floor = noise_floor_amp * times_inv ** (-0.5)
    noise_std   = np.maximum(noise_frac * np.abs(d_clean), noise_floor)
    d_obs       = d_clean + noise_std * rng.standard_normal(len(d_clean))

    print(f'{label}: {len(times_inv)} gates  '
          f'({times_inv[0]*1e3:.2f} ms – {times_inv[-1]*1e3:.1f} ms)  '
          f'noise={noise_frac*100:.0f}%')
    configs[label] = dict(
        L=L, L_circ=L_circ,
        geom_sq=geom_sq, geom_circ=geom_circ,
        rx=rx, n_quad=nq, sys_filt=None,
        d_clean=d_clean, times_inv=times_inv,
        d_obs_inv=d_obs, noise_std_inv=noise_std,
    )
print(f'\n3 configs built in {time.perf_counter()-t0:.2f} s')

fig, ax = plt.subplots(1, 1, figsize=(5, 4))
for (label, cfg), c in zip(configs.items(), ['C0', 'C1', 'C2']):
    ax.loglog(cfg['times_inv'], np.abs(cfg['d_clean']),   '-', color=c, lw=1.5)
    ax.loglog(cfg['times_inv'], np.abs(cfg['d_obs_inv']), '.', color=c, ms=5, label=label)
ax.set_xlabel('Time [s]')
ax.set_ylabel(r'$-dB_z/dt$ [V/m²]')
ax.legend()
ax.grid(True, which='both', alpha=0.5)
fig.tight_layout()
plt.show()
# Out:
# 200×200 m central: 31 gates  (0.01 ms – 10.0 ms)  noise=2%
# 50×50 m central: 31 gates  (0.01 ms – 10.0 ms)  noise=2%
# 3×3 m offset: 31 gates  (0.01 ms – 10.0 ms)  noise=2%
#
# 3 configs built in 1.19 s

# %% [markdown]
# ### 2.2 Inversion: square vs equivalent-area circle
#
# Each dataset is inverted twice, starting from a homogeneous 10 Ohm.m half-space:
#
# 1. **Square forward model** — uses the exact square-loop kernel with Gauss-Legendre quadrature over the loop sides.
# 2. **Equivalent-area circle** — replaces the square loop with a circle of equal area ($r = L / \sqrt{\pi}$), which requires only a 1-D Hankel transform and is significantly faster.
#
# Using a circular approximation is common in practice because it greatly reduces computation time while introducing only a small systematic bias, particularly for large loops relative to the skin depth. The bias grows as the loop size shrinks relative to the target depth or as the offset geometry becomes more asymmetric.

# %%
import time

# Inversion mesh: 15 layers, log-spaced depth axis down to 200 m
n_layers   = 15
depths_inv = np.geomspace(2.0, 200.0, n_layers)
thick_inv  = np.append(np.diff(depths_inv), depths_inv[-1])   # N = 15 elements

# Starting model: homogeneous 100 Ohm.m
rho_start  = np.ones(n_layers) * 10.0
lrho_start = np.log(rho_start)

results_sq   = {}
results_circ = {}
timings      = {}

for label, cfg in configs.items():
    rx_kw = dict(rx_offset=cfg['rx']) if cfg['rx'] is not None else {}
    timings[label] = {}

    common_kw = dict(
        thicknesses       = thick_inv,
        log_resistivities = lrho_start,
        times             = cfg['times_inv'],
        noise_std         = cfg['noise_std_inv'],
        max_noise_frac    = 0.0,
        alpha_start       = None,
        alpha_steps       = 10,
        alpha_step        = 3/9,
        maxit             = 15,
        transform         = 'euler',
        hankel_filter     = 'key_101',
        fourier_filter    = 'key_81',
        use_numba         = HAS_NUMBA,
        use_cuda          = HAS_CUDA,
        calc_sens         = False,
        analytical_j      = True,
        **rx_kw,
    )

    # --- Square inversion (correct geometry) ---
    print(f'[Square]  {label}  (geometry={cfg["geom_sq"]}, L={cfg["L"]:.1f} m) ...')
    t0 = time.perf_counter()
    res = invert(
        obs_data  = cfg['d_obs_inv'],
        tx_radius = cfg['L'],
        geometry  = cfg['geom_sq'],
        n_quad    = cfg['n_quad'],
        **common_kw,
    )
    timings[label]['sq'] = time.perf_counter() - t0
    results_sq[label] = res
    print(f"  Final RMS = {res['rms_history'][-1]:.3f}  ({timings[label]['sq']:.1f} s)\n")

    # --- Circle inversion (equivalent-area approximation) ---
    print(f'[Circle]  {label}  (geometry={cfg["geom_circ"]}, r={cfg["L_circ"]:.2f} m) ...')
    t0 = time.perf_counter()
    res = invert(
        obs_data  = cfg['d_obs_inv'],
        tx_radius = cfg['L_circ'],
        geometry  = cfg['geom_circ'],
        n_quad    = 1,
        **common_kw,
    )
    timings[label]['circ'] = time.perf_counter() - t0
    results_circ[label] = res
    print(f"  Final RMS = {res['rms_history'][-1]:.3f}  ({timings[label]['circ']:.1f} s)\n")

# --- Timing summary ---
print(f"\n{'Config':<22}  {'Square':>10}  {'Iters':>6}  {'Circle':>10}  {'Iters':>6}")
print('-' * 60)
for label in configs:
    n_sq   = len(results_sq[label]['rms_history'])
    n_circ = len(results_circ[label]['rms_history'])
    print(f"{label:<22}  {timings[label]['sq']:>9.1f} s  {n_sq:>6d}  "
          f"{timings[label]['circ']:>9.1f} s  {n_circ:>6d}")
# Out:
# [Square]  200×200 m central  (geometry=square_central, L=200.0 m) ...
# Building initial Jacobian...
# WARNING: 2 non-positive dbdt values (zeroed in J)
#   done (1.9 s)
# alpha_start = 1.34e+04
# Iteration   1:  RMS = 76.2194
#     alpha = 13357.305,  RMS = 21.0626
#     alpha = 6199.912,  RMS = 20.0382
#     alpha = 2877.744,  RMS = 19.3659
#     alpha = 1335.731,  RMS = 19.0611
#     alpha = 619.991,  RMS = 19.2986
#     RMS increased — stopping alpha search early.
# Iteration   2:  RMS = 19.0611
# WARNING: 1 non-positive dbdt values (zeroed in J)
#     alpha = 2877.744,  RMS = 16.5758
#     alpha = 1335.731,  RMS = 16.3720
#     alpha = 619.991,  RMS = 16.4288
#     RMS increased — stopping alpha search early.
# Iteration   3:  RMS = 16.3720
#     alpha = 2877.744,  RMS = 10.7277
#     alpha = 1335.731,  RMS = 10.6597
#     alpha = 619.991,  RMS = 10.6512
#     alpha = 287.774,  RMS = 11.0165
#     RMS increased — stopping alpha search early.
# Iteration   4:  RMS = 10.6512
#     alpha = 1335.731,  RMS = 7.7351
#     alpha = 619.991,  RMS = 8.0173
#     RMS increased — stopping alpha search early.
# Iteration   5:  RMS = 7.7351
#     alpha = 2877.744,  RMS = 6.8047
#     alpha = 1335.731,  RMS = 5.4106
#     alpha = 619.991,  RMS = 5.4130
#     RMS increased — stopping alpha search early.
# Iteration   6:  RMS = 5.4106
#     alpha = 2877.744,  RMS = 6.7757
#     alpha = 1335.731,  RMS = 4.5243
#     alpha = 619.991,  RMS = 3.3467
#     alpha = 287.774,  RMS = 3.7930
#     RMS increased — stopping alpha search early.
# Iteration   7:  RMS = 3.3467
#     alpha = 1335.731,  RMS = 4.4499
#     alpha = 619.991,  RMS = 2.5543
#     alpha = 287.774,  RMS = 1.7885
#     alpha = 133.573,  RMS = 2.2527
#     RMS increased — stopping alpha search early.
# Iteration   8:  RMS = 1.7885
#     alpha = 619.991,  RMS = 2.3956
#     alpha = 287.774,  RMS = 1.4269
#     alpha = 133.573,  RMS = 1.0416
#     alpha = 61.999,  RMS = 1.2067
#     RMS increased — stopping alpha search early.
# Iteration   9:  RMS = 1.0416
#     alpha = 287.774,  RMS = 1.4321
#     alpha = 133.573,  RMS = 0.9937
#     RMS below 1 — stopping for parabola fit.
#     Parabola: alpha* = 135,  predicted RMS = 1.00,  actual RMS = 0.9978
# Iteration  10:  RMS = 0.9978
#   RMS <= 1 — converged.
#   Final RMS = 0.998  (16.9 s)
#
# [Circle]  200×200 m central  (geometry=circle_central, r=112.84 m) ...
# Building initial Jacobian...
#   done (0.1 s)
# alpha_start = 1.34e+04
# Iteration   1:  RMS = 74.8075
#     alpha = 13413.274,  RMS = 20.4668
#     alpha = 6225.890,  RMS = 17.0827
#     alpha = 2889.802,  RMS = 14.5368
#     alpha = 1341.327,  RMS = 13.5681
#     alpha = 622.589,  RMS = 14.5385
#     RMS increased — stopping alpha search early.
# Iteration   2:  RMS = 13.5681
#     alpha = 2889.802,  RMS = 13.3378
#     alpha = 1341.327,  RMS = 14.7669
#     RMS increased — stopping alpha search early.
# Iteration   3:  RMS = 13.3378
#     alpha = 6225.890,  RMS = 8.0047
#     alpha = 2889.802,  RMS = 6.0699
#     alpha = 1341.327,  RMS = 5.0321
#     alpha = 622.589,  RMS = 5.1205
#     RMS increased — stopping alpha search early.
# Iteration   4:  RMS = 5.0321
#     alpha = 2889.802,  RMS = 6.5265
#     alpha = 1341.327,  RMS = 4.2217
#     alpha = 622.589,  RMS = 3.0505
#     alpha = 288.980,  RMS = 3.4433
#     RMS increased — stopping alpha search early.
# Iteration   5:  RMS = 3.0505
#     alpha = 1341.327,  RMS = 4.1244
#     alpha = 622.589,  RMS = 2.3835
#     alpha = 288.980,  RMS = 1.6255
#     alpha = 134.133,  RMS = 1.9887
#     RMS increased — stopping alpha search early.
# Iteration   6:  RMS = 1.6255
#     alpha = 622.589,  RMS = 2.2667
#     alpha = 288.980,  RMS = 1.3842
#     alpha = 134.133,  RMS = 1.0174
#     alpha = 62.259,  RMS = 1.0998
#     RMS increased — stopping alpha search early.
# Iteration   7:  RMS = 1.0174
#     alpha = 288.980,  RMS = 1.3962
#     alpha = 134.133,  RMS = 0.9953
#     RMS below 1 — stopping for parabola fit.
#     Parabola: alpha* = 135,  predicted RMS = 1.00,  actual RMS = 0.9981
# Iteration   8:  RMS = 0.9981
#   RMS <= 1 — converged.
#   Final RMS = 0.998  (0.8 s)
#
# [Square]  50×50 m central  (geometry=square_central, L=50.0 m) ...
# Building initial Jacobian...
#   done (1.3 s)
# alpha_start = 1.12e+04
# Iteration   1:  RMS = 74.0776
#     alpha = 11213.032,  RMS = 24.6156
#     alpha = 5204.628,  RMS = 26.8312
#     RMS increased — stopping alpha search early.
# Iteration   2:  RMS = 24.6156
#     alpha = 24157.745,  RMS = 18.0126
#     alpha = 11213.032,  RMS = 14.7576
#     alpha = 5204.628,  RMS = 14.7871
#     RMS increased — stopping alpha search early.
# Iteration   3:  RMS = 14.7576
#     alpha = 24157.745,  RMS = 15.6400
#     alpha = 11213.032,  RMS = 9.5234
#     alpha = 5204.628,  RMS = 5.6544
#     alpha = 2415.774,  RMS = 3.9774
#     alpha = 1121.303,  RMS = 3.6707
#     alpha = 520.463,  RMS = 3.8207
#     RMS increased — stopping alpha search early.
# Iteration   4:  RMS = 3.6707
#     alpha = 2415.774,  RMS = 4.1735
#     alpha = 1121.303,  RMS = 2.4906
#     alpha = 520.463,  RMS = 1.7489
#     alpha = 241.577,  RMS = 1.4103
#     alpha = 112.130,  RMS = 1.3528
#     alpha = 52.046,  RMS = 1.8226
#     RMS increased — stopping alpha search early.
# Iteration   5:  RMS = 1.3528
#     alpha = 241.577,  RMS = 1.7309
#     alpha = 112.130,  RMS = 1.2384
#     alpha = 52.046,  RMS = 1.0032
#     alpha = 24.158,  RMS = 1.0726
#     RMS increased — stopping alpha search early.
# Iteration   6:  RMS = 1.0032
#     alpha = 112.130,  RMS = 1.4256
#     alpha = 52.046,  RMS = 1.0245
#     alpha = 24.158,  RMS = 0.8874
#     RMS below 1 — stopping for parabola fit.
#     Parabola: alpha* = 48.4,  predicted RMS = 1.00,  actual RMS = 1.0027
# Iteration   7:  RMS = 0.8874
#   RMS <= 1 — converged.
#   Final RMS = 0.887  (10.9 s)
#
# [Circle]  50×50 m central  (geometry=circle_central, r=28.21 m) ...
# Building initial Jacobian...
#   done (0.2 s)
# alpha_start = 1.12e+04
# Iteration   1:  RMS = 74.3871
#     alpha = 11241.119,  RMS = 25.0310
#     alpha = 5217.665,  RMS = 27.3773
#     RMS increased — stopping alpha search early.
# Iteration   2:  RMS = 25.0310
#     alpha = 24218.257,  RMS = 18.2063
#     alpha = 11241.119,  RMS = 15.0211
#     alpha = 5217.665,  RMS = 15.1390
#     RMS increased — stopping alpha search early.
# Iteration   3:  RMS = 15.0211
#     alpha = 24218.257,  RMS = 15.7807
#     alpha = 11241.119,  RMS = 9.5910
#     alpha = 5217.665,  RMS = 5.6920
#     alpha = 2421.826,  RMS = 4.0037
#     alpha = 1124.112,  RMS = 3.7047
#     alpha = 521.767,  RMS = 3.8560
#     RMS increased — stopping alpha search early.
# Iteration   4:  RMS = 3.7047
#     alpha = 2421.826,  RMS = 4.2194
#     alpha = 1124.112,  RMS = 2.5142
#     alpha = 521.767,  RMS = 1.7576
#     alpha = 242.183,  RMS = 1.4166
#     alpha = 112.411,  RMS = 1.3510
#     alpha = 52.177,  RMS = 1.8101
#     RMS increased — stopping alpha search early.
# Iteration   5:  RMS = 1.3510
#     alpha = 242.183,  RMS = 1.7450
#     alpha = 112.411,  RMS = 1.2514
#     alpha = 52.177,  RMS = 1.0134
#     alpha = 24.218,  RMS = 1.0830
#     RMS increased — stopping alpha search early.
# Iteration   6:  RMS = 1.0134
#     alpha = 112.411,  RMS = 1.4425
#     alpha = 52.177,  RMS = 1.0375
#     alpha = 24.218,  RMS = 0.8932
#     RMS below 1 — stopping for parabola fit.
#     Parabola: alpha* = 46.6,  predicted RMS = 1.00,  actual RMS = 1.0049
# Iteration   7:  RMS = 0.8932
#   RMS <= 1 — converged.
#   Final RMS = 0.893  (1.1 s)
#
# [Square]  3×3 m offset  (geometry=square_offset, L=3.0 m) ...
# Building initial Jacobian...
#   done (11.8 s)
# alpha_start = 1.59e+04
# Iteration   1:  RMS = 66.7336
#     alpha = 15863.705,  RMS = 24.7838
#     alpha = 7363.280,  RMS = 27.3796
#     RMS increased — stopping alpha search early.
# Iteration   2:  RMS = 24.7838
#     alpha = 34177.316,  RMS = 15.5335
#     alpha = 15863.705,  RMS = 11.3947
#     alpha = 7363.280,  RMS = 8.9116
#     alpha = 3417.732,  RMS = 8.2483
#     alpha = 1586.370,  RMS = 8.7053
#     RMS increased — stopping alpha search early.
# Iteration   3:  RMS = 8.2483
#     alpha = 7363.280,  RMS = 8.7877
#     alpha = 3417.732,  RMS = 5.2097
#     alpha = 1586.370,  RMS = 3.1514
#     alpha = 736.328,  RMS = 2.2524
#     alpha = 341.773,  RMS = 1.8387
#     alpha = 158.637,  RMS = 1.6199
#     alpha = 73.633,  RMS = 1.6579
#     RMS increased — stopping alpha search early.
# Iteration   4:  RMS = 1.6199
#     alpha = 341.773,  RMS = 1.9318  (step = 0.25)
#     alpha = 158.637,  RMS = 1.7635  (step = 0.25)
#     alpha = 73.633,  RMS = 1.5997  (step = 0.25)
#     alpha = 34.177,  RMS = 1.3500  (step = 0.50)
#     alpha = 15.864,  RMS = 1.1440  (step = 0.50)
#     alpha = 7.363,  RMS = 1.0691
#     alpha = 3.418,  RMS = 1.2264
#     RMS increased — stopping alpha search early.
# Iteration   5:  RMS = 1.0691
#     alpha = 15.864,  RMS = 0.9471  (step = 0.50)
#     RMS below 1 — stopping for parabola fit.
# Iteration   6:  RMS = 0.9471
#   RMS <= 1 — converged.
#   Final RMS = 0.947  (76.9 s)
#
# [Circle]  3×3 m offset  (geometry=circle_offset, r=1.69 m) ...
# Building initial Jacobian...
#   done (0.1 s)
# alpha_start = 1.59e+04
# Iteration   1:  RMS = 66.7369
#     alpha = 15865.349,  RMS = 24.7852
#     alpha = 7364.043,  RMS = 27.3810
#     RMS increased — stopping alpha search early.
# Iteration   2:  RMS = 24.7852
#     alpha = 34180.858,  RMS = 15.5343
#     alpha = 15865.349,  RMS = 11.3953
#     alpha = 7364.043,  RMS = 8.9122
#     alpha = 3418.086,  RMS = 8.2489
#     alpha = 1586.535,  RMS = 8.7060
#     RMS increased — stopping alpha search early.
# Iteration   3:  RMS = 8.2489
#     alpha = 7364.043,  RMS = 8.7883
#     alpha = 3418.086,  RMS = 5.2101
#     alpha = 1586.535,  RMS = 3.1516
#     alpha = 736.404,  RMS = 2.2525
#     alpha = 341.809,  RMS = 1.8388
#     alpha = 158.653,  RMS = 1.6201
#     alpha = 73.640,  RMS = 1.6580
#     RMS increased — stopping alpha search early.
# Iteration   4:  RMS = 1.6201
#     alpha = 341.809,  RMS = 1.9319  (step = 0.25)
#     alpha = 158.653,  RMS = 1.7636  (step = 0.25)
#     alpha = 73.640,  RMS = 1.5996  (step = 0.25)
#     alpha = 34.181,  RMS = 1.3498  (step = 0.50)
#     alpha = 15.865,  RMS = 1.1439  (step = 0.50)
#     alpha = 7.364,  RMS = 1.0692
#     alpha = 3.418,  RMS = 1.2267
#     RMS increased — stopping alpha search early.
# Iteration   5:  RMS = 1.0692
#     alpha = 15.865,  RMS = 0.9477  (step = 0.50)
#     RMS below 1 — stopping for parabola fit.
# Iteration   6:  RMS = 0.9477
#   RMS <= 1 — converged.
#   Final RMS = 0.948  (0.6 s)
#
#
# Config                      Square   Iters      Circle   Iters
# ------------------------------------------------------------
# 200×200 m central            16.9 s      10        0.8 s       8
# 50×50 m central              10.9 s       7        1.1 s       7
# 3×3 m offset                 76.9 s       6        0.6 s       6

# %% [markdown]
# ### 2.3 Recovery: data fit and model comparison
#
# The 3×3 figure below shows, for each configuration:
# - **Row 1:** Data fit — observed data (black dots) overlaid with predictions from the square and circle inversions.
# - **Row 2:** Model recovery — inverted resistivity profiles against the true model (dashed black).
# - **Row 3:** Model difference — relative difference $(\rho_\text{circ} - \rho_\text{sq}) / \rho_\text{sq}$ [%], quantifying the bias introduced by the circular approximation.

# %%
# True model step function
deps_t = np.concatenate(([0], np.cumsum(thick_true), [depths_inv[-1]]))
rho_t  = np.concatenate([np.repeat(rho_true[:-1], 2), [rho_true[-1], rho_true[-1]]])
dep_t  = np.repeat(deps_t, 2)[1:-1]

def make_dpred(cfg, res, geom, L, nq):
    thick_r   = res['thicknesses'][:-1]
    rho_inv   = res['resistivities']
    t         = cfg['times_inv']
    kw        = dict(transform='dlf', hankel_filter='key_101', fourier_filter='key_81')
    if geom == 'circle_central':
        return -fwd_circle_central(thick_r, rho_inv, L, t, **kw)
    elif geom == 'circle_offset':
        return -fwd_circle_offset(thick_r, rho_inv, L, cfg['rx'], t, **kw)
    elif geom == 'square_central':
        return -fwd_square_central(thick_r, rho_inv, L, t, n_quad=nq, **kw)
    else:
        return -fwd_square_offset(thick_r, rho_inv, L, cfg['rx'], 0.0, t, n_quad=nq, **kw)

depth_mids = np.concatenate(([0], np.cumsum(thick_inv[:-1])))

fig, axs = plt.subplots(3, 3, figsize=(13, 10),
                        gridspec_kw={'height_ratios': [1, 1, 1]},
                        sharey='row', sharex='row')

for j, (label, cfg) in enumerate(configs.items()):
    res_sq   = results_sq[label]
    res_circ = results_circ[label]

    inv_times   = cfg['times_inv']
    obs_trimmed = cfg['d_obs_inv']

    d_pred_sq   = make_dpred(cfg, res_sq,   cfg['geom_sq'],   cfg['L'],      cfg['n_quad'])
    d_pred_circ = make_dpred(cfg, res_circ, cfg['geom_circ'], cfg['L_circ'], 1)

    # --- Row 0: Data misfit ---
    ax = axs[0, j]
    ax.loglog(inv_times, obs_trimmed, 'o',  ms=4, color='k',  label='Observed', zorder=3)
    ax.loglog(inv_times, d_pred_sq,   '-',  lw=2, color='C0', label=f"Square FWD (RMS={res_sq['rms_history'][-1]:.2f})")
    ax.loglog(inv_times, d_pred_circ, '-',  lw=2, color='C1', label=f"Circle FWD (RMS={res_circ['rms_history'][-1]:.2f})")
    ax.set_title(label)
    ax.set_xlabel('Time [s]')
    ax.legend(fontsize=8)
    ax.grid(True, which='both', alpha=0.3)

    # --- Row 1: Model recovery ---
    ax = axs[1, j]
    for res, color, tag in [(res_sq, 'C0', 'Square FWD'), (res_circ, 'C1', 'Circle FWD')]:
        thick_r  = res['thicknesses'][:-1]
        rho_inv  = res['resistivities']
        depths_r = np.concatenate(([0], np.cumsum(thick_r)))
        rho_step = np.repeat(rho_inv, 2)
        dep_step = np.repeat(np.append(depths_r, depths_inv[-1]), 2)[1:-1]
        ax.semilogx(rho_step, dep_step, '-', lw=2, color=color, label=tag)
    ax.semilogx(rho_t, dep_t, '--', lw=1.5, color='k', label='True')
    ax.legend(fontsize=8)
    ax.grid(True, which='both', alpha=0.3)
    ax.set_xlabel('Resistivity [Ohm.m]')

    # --- Row 2: Model difference (%) ---
    rho_sq_inv   = res_sq['resistivities']
    rho_circ_inv = res_circ['resistivities']
    delta_pct    = (rho_circ_inv - rho_sq_inv) / rho_sq_inv * 100.0
    dep_step     = np.repeat(np.append(depth_mids, depths_inv[-1]), 2)[1:-1]
    delta_step   = np.repeat(delta_pct, 2)

    ax = axs[2, j]
    ax.plot(delta_step, dep_step, '-', lw=2, color='C2')
    ax.axvline(0, color='k', lw=0.8, ls='--')
    ax.set_xlabel(r'Difference [%]')
    ax.grid(True, which='both', alpha=0.3)

# Invert depth axes once — calling invert_yaxis() inside the column loop
# toggles the shared axis each time (sharey='row'), which flips the result
# when the number of configs is even.
axs[1, 0].invert_yaxis()
axs[2, 0].invert_yaxis()

axs[0, 0].set_ylabel(r'$-dB_z/dt$ [V/m²]')
axs[1, 0].set_ylabel('Depth [m]')
axs[2, 0].set_ylabel('Depth [m]')
fig.tight_layout()
plt.show()

# %% [markdown]
# ### 2.4 Circle warm-start
#
# For square-loop geometries the forward model is significantly more expensive than the equivalent-area circle (Gauss-Legendre quadrature over the loop sides vs a single Hankel transform).  The `circle_warmstart=True` flag exploits this by:
#
# 1. Running the full Gauss-Newton inversion with the circle model until convergence.
# 2. Taking the converged model as a starting point and doing **one** refinement step with the exact square forward model.
#
# This gives a result very close to a pure square inversion at a fraction of the cost.  The example below runs all three configurations with `circle_warmstart=True` and compares the timing and final RMS against the pure square result.

# %%
import time
results_ws = {}
timings_ws = {}

for label, cfg in configs.items():
    if not cfg['geom_sq'].startswith('square'):
        continue
    rx_kw = dict(rx_offset=cfg['rx']) if cfg['rx'] is not None else {}

    t0 = time.perf_counter()
    res = invert(
        obs_data          = cfg['d_obs_inv'],
        thicknesses       = thick_inv,
        log_resistivities = lrho_start,
        tx_radius         = cfg['L'],
        times             = cfg['times_inv'],
        noise_std         = cfg['noise_std_inv'],
        max_noise_frac    = 0.0,
        alpha_start       = None,
        alpha_steps       = 10,
        maxit             = 15,
        transform         = 'euler',
        hankel_filter     = 'key_101',
        fourier_filter    = 'key_81',
        use_numba         = HAS_NUMBA,
        use_cuda          = HAS_CUDA,
        calc_sens         = False,
        analytical_j      = True,
        geometry          = cfg['geom_sq'],
        n_quad            = cfg['n_quad'],
        circle_warmstart  = True,
        **rx_kw,
    )
    timings_ws[label] = time.perf_counter() - t0
    results_ws[label] = res

# --- Comparison table ---
print(f"\n{'Config':<22}  {'Square (pure)':>14}  {'Warm-start':>12}  {'ΔRMS':>8}")
print('-' * 65)
for label in results_ws:
    rms_sq = results_sq[label]['rms_history'][-1]
    rms_ws = results_ws[label]['rms_history'][-1]
    t_sq   = timings[label]['sq']
    t_ws   = timings_ws[label]
    print(f"{label:<22}  {t_sq:>9.1f} s  {rms_sq:>5.3f}  "
          f"{t_ws:>7.1f} s  {rms_ws:>5.3f}  {rms_ws - rms_sq:>+8.4f}")
# Out:
# [circle_warmstart] Running circle pre-inversion (geometry=circle_central, r=112.838 m)...
# Building initial Jacobian...
#   done (0.1 s)
# alpha_start = 1.34e+04
# Iteration   1:  RMS = 74.8075
#     alpha = 13413.274,  RMS = 20.4668
#     alpha = 10385.411,  RMS = 19.2908
#     alpha = 8041.047,  RMS = 18.1548
#     alpha = 6225.890,  RMS = 17.0827
#     alpha = 4820.481,  RMS = 16.1027
#     alpha = 3732.323,  RMS = 15.2444
#     alpha = 2889.802,  RMS = 14.5368
#     alpha = 2237.469,  RMS = 14.0073
#     alpha = 1732.391,  RMS = 13.6790
#     alpha = 1341.327,  RMS = 13.5681
# Iteration   2:  RMS = 13.5681
#     alpha = 1732.391,  RMS = 14.1134
#     alpha = 1341.327,  RMS = 14.7669
#     alpha = 1038.541,  RMS = 15.5842
#     alpha = 804.105,  RMS = 16.5283
#     alpha = 622.589,  RMS = 17.5500
#     alpha = 482.048,  RMS = 18.6001
#     alpha = 373.232,  RMS = 19.6401
#     alpha = 288.980,  RMS = 20.6455
#     alpha = 223.747,  RMS = 21.6047
#     alpha = 173.239,  RMS = 22.5157
#   No improvement found — stopping.
# [circle_warmstart] Circle converged (RMS=13.568). Running up to 15 square refinement steps...
# Building initial Jacobian...
#   done (1.2 s)
# alpha_start = 2.27e+03
# Iteration   1:  RMS = 13.7204
#     alpha = 2271.386,  RMS = 11.4519
#     alpha = 1758.651,  RMS = 11.2945
#     alpha = 1361.660,  RMS = 11.1941
#     alpha = 1054.284,  RMS = 11.1610
#     alpha = 816.294,  RMS = 11.2078
#     RMS increased — stopping alpha search early.
# Iteration   2:  RMS = 11.1610
#     alpha = 1361.660,  RMS = 5.1679
#     alpha = 1054.284,  RMS = 4.8990
#     alpha = 816.294,  RMS = 4.8372
#     alpha = 632.027,  RMS = 4.9604
#     RMS increased — stopping alpha search early.
# Iteration   3:  RMS = 4.8372
#     alpha = 1054.284,  RMS = 4.0288
#     alpha = 816.294,  RMS = 3.3987
#     alpha = 632.027,  RMS = 2.9726
#     alpha = 489.355,  RMS = 2.8113
#     alpha = 378.890,  RMS = 2.9041
#     RMS increased — stopping alpha search early.
# Iteration   4:  RMS = 2.8113
#     alpha = 632.027,  RMS = 2.4794
#     alpha = 489.355,  RMS = 2.0583
#     alpha = 378.890,  RMS = 1.7374
#     alpha = 293.361,  RMS = 1.5287
#     alpha = 227.139,  RMS = 1.4472
#     alpha = 175.865,  RMS = 1.4959
#     RMS increased — stopping alpha search early.
# Iteration   5:  RMS = 1.4472
#     alpha = 293.361,  RMS = 1.4259
#     alpha = 227.139,  RMS = 1.2400
#     alpha = 175.865,  RMS = 1.0991
#     alpha = 136.166,  RMS = 0.9983
#     RMS below 1 — stopping for parabola fit.
#     Parabola: alpha* = 137,  predicted RMS = 1.00,  actual RMS = 1.0004
# Iteration   6:  RMS = 0.9983
#   RMS <= 1 — converged.
# [circle_warmstart] Running circle pre-inversion (geometry=circle_central, r=28.209 m)...
# Building initial Jacobian...
#   done (0.2 s)
# alpha_start = 1.12e+04
# Iteration   1:  RMS = 74.3871
#     alpha = 11241.119,  RMS = 25.0310
#     alpha = 8703.590,  RMS = 25.3864
#     RMS increased — stopping alpha search early.
# Iteration   2:  RMS = 25.0310
#     alpha = 14518.464,  RMS = 15.6276
#     alpha = 11241.119,  RMS = 15.0211
#     alpha = 8703.590,  RMS = 14.8101
#     alpha = 6738.874,  RMS = 14.8855
#     RMS increased — stopping alpha search early.
# Iteration   3:  RMS = 14.8101
#     alpha = 11241.119,  RMS = 10.1106
#     alpha = 8703.590,  RMS = 8.3734
#     alpha = 6738.874,  RMS = 6.9121
#     alpha = 5217.665,  RMS = 5.7179
#     alpha = 4039.849,  RMS = 4.7814
#     alpha = 3127.908,  RMS = 4.0877
#     alpha = 2421.826,  RMS = 3.6104
#     alpha = 1875.132,  RMS = 3.3103
#     alpha = 1451.846,  RMS = 3.1406
#     alpha = 1124.112,  RMS = 3.0579
# Iteration   4:  RMS = 3.0579
#     alpha = 1451.846,  RMS = 2.9512
#     alpha = 1124.112,  RMS = 2.5205
#     alpha = 870.359,  RMS = 2.1935
#     alpha = 673.887,  RMS = 1.9468
#     alpha = 521.767,  RMS = 1.7601
#     alpha = 403.985,  RMS = 1.6168
#     alpha = 312.791,  RMS = 1.5046
#     alpha = 242.183,  RMS = 1.4161
#     alpha = 187.513,  RMS = 1.3508
#     alpha = 145.185,  RMS = 1.3168
# Iteration   5:  RMS = 1.3168
#     alpha = 187.513,  RMS = 1.4374
#     alpha = 145.185,  RMS = 1.3230
#     alpha = 112.411,  RMS = 1.2277
#     alpha = 87.036,  RMS = 1.1445
#     alpha = 67.389,  RMS = 1.0771
#     alpha = 52.177,  RMS = 1.0444
#     alpha = 40.398,  RMS = 1.0716
#     RMS increased — stopping alpha search early.
# Iteration   6:  RMS = 1.0444
#     alpha = 67.389,  RMS = 1.1275
#     alpha = 52.177,  RMS = 1.0369
#     alpha = 40.398,  RMS = 0.9671
#     RMS below 1 — stopping for parabola fit.
#     Parabola: alpha* = 46,  predicted RMS = 1.00,  actual RMS = 1.0006
# Iteration   7:  RMS = 0.9671
#   RMS <= 1 — converged.
# [circle_warmstart] Circle converged (RMS=0.967). Running up to 15 square refinement steps...
# Building initial Jacobian...
#   done (2.5 s)
# alpha_start = 89.8
# Iteration   1:  RMS = 0.9906
#   RMS <= 1 — converged.
# [circle_warmstart] Running circle pre-inversion (geometry=circle_offset, r=1.693 m)...
# Building initial Jacobian...
#   done (0.1 s)
# alpha_start = 1.59e+04
# Iteration   1:  RMS = 66.7369
#     alpha = 15865.349,  RMS = 24.7852
#     alpha = 12283.964,  RMS = 25.4912
#     RMS increased — stopping alpha search early.
# Iteration   2:  RMS = 24.7852
#     alpha = 20490.886,  RMS = 12.6066
#     alpha = 15865.349,  RMS = 11.3953
#     alpha = 12283.964,  RMS = 10.3680
#     alpha = 9511.027,  RMS = 9.5364
#     alpha = 7364.043,  RMS = 8.9122
#     alpha = 5701.711,  RMS = 8.4999
#     alpha = 4414.628,  RMS = 8.2888
#     alpha = 3418.086,  RMS = 8.2489
#     alpha = 2646.500,  RMS = 8.3360
#     RMS increased — stopping alpha search early.
# Iteration   3:  RMS = 8.2489
#     alpha = 4414.628,  RMS = 6.2288
#     alpha = 3418.086,  RMS = 5.2101
#     alpha = 2646.500,  RMS = 4.3626
#     alpha = 2049.089,  RMS = 3.6805
#     alpha = 1586.535,  RMS = 3.1516
#     alpha = 1228.396,  RMS = 2.7559
#     alpha = 951.103,  RMS = 2.4662
#     alpha = 736.404,  RMS = 2.2525
#     alpha = 570.171,  RMS = 2.0879
#     alpha = 441.463,  RMS = 1.9534
# Iteration   4:  RMS = 1.9534
#     alpha = 570.171,  RMS = 2.3055  (step = 0.50)
#     alpha = 441.463,  RMS = 2.1915  (step = 0.50)
#     alpha = 341.809,  RMS = 2.0782  (step = 0.50)
#     alpha = 264.650,  RMS = 1.9685  (step = 0.50)
#     alpha = 204.909,  RMS = 1.8688  (step = 0.50)
#     alpha = 158.653,  RMS = 1.7839  (step = 0.50)
#     alpha = 122.840,  RMS = 1.7105  (step = 0.50)
#     alpha = 95.110,  RMS = 1.6376  (step = 0.50)
#     alpha = 73.640,  RMS = 1.5596  (step = 0.50)
#     alpha = 57.017,  RMS = 1.4850  (step = 0.50)
# Iteration   5:  RMS = 1.4850
#     alpha = 73.640,  RMS = 1.1259
#     alpha = 57.017,  RMS = 1.2070  (step = 0.50)
#     RMS increased — stopping alpha search early.
# Iteration   6:  RMS = 1.1259
#     alpha = 95.110,  RMS = 1.3045
#     alpha = 73.640,  RMS = 1.1674
#     alpha = 57.017,  RMS = 1.0473
#     alpha = 44.146,  RMS = 0.9444
#     RMS below 1 — stopping for parabola fit.
#     Parabola: alpha* = 51,  predicted RMS = 1.00,  actual RMS = 0.9996
# Iteration   7:  RMS = 0.9996
#   RMS <= 1 — converged.
# [circle_warmstart] Circle converged (RMS=1.000). Running up to 15 square refinement steps...
# Building initial Jacobian...
#   done (17.1 s)
# alpha_start = 18.9
# Iteration   1:  RMS = 0.9994
#   RMS <= 1 — converged.
#
# Config                   Square (pure)    Warm-start      ΔRMS
# -----------------------------------------------------------------
# 200×200 m central            16.9 s  0.998     11.3 s  0.998   +0.0006
# 50×50 m central              10.9 s  0.887      4.0 s  0.991   +0.1031
# 3×3 m offset                 76.9 s  0.947     18.7 s  0.999   +0.0524

# %%
# --- Recovery comparison: pure square vs warm-start ---
fig, axs = plt.subplots(1, len(results_ws), figsize=(13, 4), sharey=True)

for j, (label, cfg) in enumerate([item for item in configs.items()
                                   if item[1]['geom_sq'].startswith('square')]):
    res_sq_pure = results_sq[label]
    res_ws_     = results_ws[label]

    thick_r = res_sq_pure['thicknesses'][:-1]
    depths_r = np.concatenate(([0], np.cumsum(thick_r)))

    ax = axs[j] if len(results_ws) > 1 else axs

    for res, color, tag in [
        (res_sq_pure, 'C0', f"Square (RMS={res_sq_pure['rms_history'][-1]:.3f})"),
        (res_ws_,     'C3', f"Warm-start (RMS={res_ws_['rms_history'][-1]:.3f})"),
    ]:
        rho_inv  = res['resistivities']
        rho_step = np.repeat(rho_inv, 2)
        dep_step = np.repeat(np.append(depths_r, depths_inv[-1]), 2)[1:-1]
        ax.semilogx(rho_step, dep_step, '-', lw=2, color=color, label=tag)

    ax.semilogx(rho_t, dep_t, '--', lw=1.5, color='k', label='True')
    ax.set_title(label)
    ax.set_xlabel('Resistivity [Ohm.m]')
    ax.invert_yaxis()
    ax.legend()
    ax.grid(True, which='both', alpha=0.3)

axs[0].set_ylabel('Depth [m]')
fig.tight_layout()
plt.show()
